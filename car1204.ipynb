# %%
# package 불러오기 
import pandas as pd
import numpy as np
import folium
import matplotlib.pyplot as plt 
import requests


#한글폰트 관련 
import matplotlib.font_manager as fm
import requests
font_name=fm.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font',family=font_name)

# %%
#전기차 엑셀파일 불러오기 
elec_df=pd.read_excel('elec_car01.xlsx')
elec_df.head()
# Out:
#          년월    서울   부산    대구   인천   광주   대전   울산  세종    경기   강원   충북   충남  \
# 0  2018. 01  1201  396   638  251  200  106  191  26   833  177  102  181
# 1  2018. 02  1202  424   630  258  202  110  193  26   851  179  103  180
# 2  2018. 03  1289  452   747  277  220  133  200  29   964  199  115  185
# 3  2018. 04  1408  492   822  300  248  151  225  49  1091  226  195  224
# 4  2018. 05  1644  610  1021  368  308  187  280  57  1355  269  227  264
#
#     전북   전남   경북   경남    제주
# 0  142  407  267  462  3331
# 1  145  414  275  468  3346
# 2  157  442  290  517  3377
# 3  197  479  345  560  3491
# 4  235  532  394  625  3541

# %%
# 전기차 숫자데이타만 불러오기 
elec_num=elec_df.loc[:,'서울':]
elec_num.head()
# Out:
#      서울   부산    대구   인천   광주   대전   울산  세종    경기   강원   충북   충남   전북   전남  \
# 0  1201  396   638  251  200  106  191  26   833  177  102  181  142  407
# 1  1202  424   630  258  202  110  193  26   851  179  103  180  145  414
# 2  1289  452   747  277  220  133  200  29   964  199  115  185  157  442
# 3  1408  492   822  300  248  151  225  49  1091  226  195  224  197  479
# 4  1644  610  1021  368  308  187  280  57  1355  269  227  264  235  532
#
#     경북   경남    제주
# 0  267  462  3331
# 1  275  468  3346
# 2  290  517  3377
# 3  345  560  3491
# 4  394  625  3541

# %%
# fuel 파일 불러오기 
fuel_df=pd.read_excel('fuel_car01.xlsx') 
fuel_df.head()
# Out:
#          년월       서울       부산      대구       인천      광주      대전      울산  \
# 0  2018. 01  2643177  1088666  958979  1268157  535707  549043  460716
# 1  2018. 02  2643317  1091492  960286  1272896  536338  549229  461396
# 2  2018. 03  2643039  1094475  962578  1277685  537527  549922  462642
# 3  2018. 04  2646341  1098482  963901  1282664  538609  550994  463830
# 4  2018. 05  2647416  1101881  965639  1287148  539578  551570  464640
#
#        세종       경기      강원      충북      충남      전북      전남       경북       경남  \
# 0  112123  4391093  562318  600260  796339  671863  714511  1025050  1316339
# 1  114005  4401156  563289  601707  799108  673028  716281  1026505  1318231
# 2  115849  4419701  565157  603992  802670  674568  719811  1028907  1321802
# 3  117703  4439557  567011  606479  805577  677150  722820  1031583  1324208
# 4  119168  4458428  568368  608568  807971  679042  726511  1034074  1325821
#
#        제주
# 0  400276
# 1  403364
# 2  407739
# 3  412303
# 4  416861

# %%
fuel_num=fuel_df.loc[:,'서울':]
fuel_num.head()
# Out:
#         서울       부산      대구       인천      광주      대전      울산      세종       경기  \
# 0  2643177  1088666  958979  1268157  535707  549043  460716  112123  4391093
# 1  2643317  1091492  960286  1272896  536338  549229  461396  114005  4401156
# 2  2643039  1094475  962578  1277685  537527  549922  462642  115849  4419701
# 3  2646341  1098482  963901  1282664  538609  550994  463830  117703  4439557
# 4  2647416  1101881  965639  1287148  539578  551570  464640  119168  4458428
#
#        강원      충북      충남      전북      전남       경북       경남      제주
# 0  562318  600260  796339  671863  714511  1025050  1316339  400276
# 1  563289  601707  799108  673028  716281  1026505  1318231  403364
# 2  565157  603992  802670  674568  719811  1028907  1321802  407739
# 3  567011  606479  805577  677150  722820  1031583  1324208  412303
# 4  568368  608568  807971  679042  726511  1034074  1325821  416861

# %%
#전기차 차량 2020.10월 기준 숫자 
elec_num=elec_df.iloc[33:34,1:18]
elec_num
# Out:
#        서울    부산    대구    인천    광주    대전    울산   세종     경기    강원    충북    충남  \
# 33  16960  4216  9068  4027  3003  3400  3433  864  15499  3362  3088  4196
#
#       전북    전남    경북    경남     제주
# 33  2498  3649  4028  4850  12305

# %%
# 서울 
fig, ax0 = plt.subplots(figsize=(12,5))
ax1 = ax0.twinx()

ax0.set_title("서울 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['서울'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['서울'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
#경기 
fig, ax0 = plt.subplots(figsize=(10,5))
ax1 = ax0.twinx()

ax0.set_title("경기 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['경기'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['경기'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
fig, ax0 = plt.subplots(figsize=(10,5))
ax1 = ax0.twinx()

ax0.set_title("부산 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['부산'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['부산'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
fig, ax0 = plt.subplots(figsize=(10,5))
ax1 = ax0.twinx()

ax0.set_title("대구 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['대구'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['대구'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
fig, ax0 = plt.subplots(figsize=(10,5))
ax1 = ax0.twinx()

ax0.set_title("대전 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['대전'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['대전'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
fig, ax0 = plt.subplots(figsize=(10,5))
ax1 = ax0.twinx()

ax0.set_title("울산 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['울산'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['울산'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
fig, ax0 = plt.subplots(figsize=(10,5))
ax1 = ax0.twinx()

ax0.set_title("제주 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['제주'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['제주'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
fig, ax0 = plt.subplots(figsize=(10,5))
ax1 = ax0.twinx()

ax0.set_title("대전 elec car vs fuel car 추이")
ax0.plot(elec_df['년월'],elec_df['대전'],label= 'elec car', color='g',linewidth=3)
ax0.set_xlabel("년월")
ax0.set_ylabel("전기차등록대수", color='red')
ax0.legend(loc='upper left')

ax1.plot(fuel_df['년월'],fuel_df['대전'],label= 'fuel car',color='r',linewidth=3)
ax1.set_ylabel("fuel차등록대수", color='red')
ax1.legend(loc='lower right')

plt.show()

# %%
#전기차 10월 기준 지역별 숫자 
elec_num=elec_df.iloc[33:,1:]
elec_num.T
# Out:
#        33
# 서울  16960
# 부산   4216
# 대구   9068
# 인천   4027
# 광주   3003
# 대전   3400
# 울산   3433
# 세종    864
# 경기  15499
# 강원   3362
# 충북   3088
# 충남   4196
# 전북   2498
# 전남   3649
# 경북   4028
# 경남   4850
# 제주  12305

# %%
#일반차 10월 기준 지역별 숫자 
fuel_num=fuel_df.iloc[33:,1:]
fuel_num.T
# Out:
#          33
# 서울  2688882
# 부산  1179020
# 대구  1014256
# 인천  1416606
# 광주   571431
# 대전   571765
# 울산   481654
# 세종   149600
# 경기  4911944
# 강원   610510
# 충북   666032
# 충남   869884
# 전북   718748
# 전남   793410
# 경북  1089190
# 경남  1402611
# 제주   509869

# %%
#전기차 일반차 지역별 숫자 
result = pd.concat([elec_num,fuel_num])
result
# Out:
#          서울       부산       대구       인천      광주      대전      울산      세종  \
# 33    16960     4216     9068     4027    3003    3400    3433     864
# 33  2688882  1179020  1014256  1416606  571431  571765  481654  149600
#
#          경기      강원      충북      충남      전북      전남       경북       경남      제주
# 33    15499    3362    3088    4196    2498    3649     4028     4850   12305
# 33  4911944  610510  666032  869884  718748  793410  1089190  1402611  509869

# %%
# 전체 승용차 차량 중 전기차 비율, 0.5% 
rate = round(elec_num.T.sum()/fuel_num.T.sum()*100,2)
rate
# Out:
# 33    0.5
# dtype: float64

# %%
# 지역별 승용차 차량 대비 전기차 비율 (제주,대구,울산)
elec_num.sum()
rate_elec_all =  (elec_num.T/fuel_num.T)*100
rate_elec_all
# Out:
#           33
# 서울  0.630745
# 부산  0.357585
# 대구  0.894054
# 인천  0.284271
# 광주  0.525523
# 대전  0.594650
# 울산  0.712752
# 세종  0.577540
# 경기  0.315537
# 강원  0.550687
# 충북  0.463641
# 충남  0.482363
# 전북  0.347549
# 전남  0.459914
# 경북  0.369816
# 경남  0.345784
# 제주  2.413365

# %%
#2018 전기차 년도별 증가율 
inc_year_elec = ((elec_df.T.iloc[1:,11]-elec_df.T.iloc[1:,0])/elec_df.T.iloc[1:,0])*100
inc_year_elec
# Out:
# 서울    296.003
# 부산    156.061
# 대구    588.871
# 인천    219.124
# 광주      443.5
# 대전    864.151
# 울산     376.44
# 세종    738.462
# 경기    368.788
# 강원    405.085
# 충북     699.02
# 충남     302.21
# 전북    335.211
# 전남    143.243
# 경북     284.27
# 경남    200.866
# 제주     142.81
# dtype: object

# %%
#2019전기차 년도별 증가율 
inc_year_elec = (elec_df.T.iloc[1:,23]-elec_df.T.iloc[1:,12])/elec_df.T.iloc[1:,12]*100
inc_year_elec
# Out:
# 서울    106.617
# 부산    198.354
# 대구    81.2714
# 인천    169.174
# 광주    115.037
# 대전    124.451
# 울산    162.514
# 세종    194.248
# 경기    131.804
# 강원    123.899
# 충북    151.652
# 충남    245.553
# 전북    124.679
# 전남    122.421
# 경북    182.755
# 경남    119.943
# 제주    37.2364
# dtype: object

# %%
#2020전기차 년도별 증가율 
inc_year_elec = (elec_df.T.iloc[1:,33]-elec_df.T.iloc[1:,24])/elec_df.T.iloc[1:,24]*100
inc_year_elec
# Out:
# 서울    69.6509
# 부산    36.5727
# 대구    7.51719
# 인천    81.7238
# 광주    28.7184
# 대전    42.4979
# 울산    39.6664
# 세종     29.148
# 경기    68.9448
# 강원    64.9657
# 충북    49.1067
# 충남    63.3956
# 전북    76.2879
# 전남    62.6114
# 경북    36.2191
# 경남     54.557
# 제주    10.3488
# dtype: object

# %%
#인구 데이타  불러오기 
popu_df = pd.read_excel('population01.xlsx')
popu_df.head()
# Out:
#          년월       서울       부산       대구       인천       광주       대전       울산  \
# 0  2018. 01  9851767  3467055  2474309  2950771  1464037  1501378  1164489
# 1  2018. 02  9845336  3465407  2473466  2951629  1463100  1499187  1163151
# 2  2018. 03  9838892  3463103  2472175  2951442  1462033  1497572  1162074
# 3  2018. 04  9830452  3460707  2471136  2952476  1460972  1496123  1161303
# 4  2018. 05  9820971  3458134  2469936  2953255  1460564  1495234  1160657
#
#        세종        경기       강원       충북       충남       전북       전남       경북  \
# 0  283198  12890445  1548078  1593903  2117685  1851694  1893444  2688747
# 1  288079  12908010  1546259  1594066  2118099  1849543  1891308  2685633
# 2  291182  12925761  1546152  1594708  2119468  1848066  1890423  2683661
# 3  295041  12941604  1545452  1595164  2120666  1847089  1890412  2682897
# 4  297604  12958648  1545291  1595822  2121618  1846144  1889726  2682316
#
#         경남      제주
# 0  3379981  658167
# 1  3378430  659189
# ...

# %%
#인구 대비 전기차 비율 (update)

elec_popu_rate = elec_df.T.iloc[1:,33].astype('int')/popu_df.T.iloc[1:,33].astype('int')*100
#elec_popu_rate = elec_df.T.iloc[1:,33]/popu_df.T.iloc[1:,33]
elec_popu_rate
# Out:
# 서울    0.175041
# 부산    0.124088
# 대구    0.374066
# 인천    0.136869
# 광주    0.206677
# 대전    0.231678
# 울산    0.301516
# 세종    0.246149
# 경기    0.115659
# 강원    0.218052
# 충북    0.193108
# 충남    0.197892
# 전북    0.138322
# 전남    0.197171
# 경북    0.152589
# 경남    0.145087
# 제주    1.826736
# Name: 33, dtype: float64

# %%
# 충전소 데이타 불러오기 
char_df = pd.read_excel('충전소리스트.xls')
char_df.head()
# Out:
#              운영기관               충전소  충전기ID            충전기타입      지역   시군구  \
# 0  환경부(한국자동차환경협회)          종묘 공영주차장      1       DC차데모+AC3상  서울특별시   종로구
# 1  환경부(한국자동차환경협회)         세종로 공영주차장      1  DC차데모+AC3상+DC콤보  서울특별시   종로구
# 2  환경부(한국자동차환경협회)        그랜드앰배서더 서울      1  DC차데모+AC3상+DC콤보  서울특별시    중구
# 3  환경부(한국자동차환경협회)        한강진역 공영주차장      1       DC차데모+AC3상  서울특별시   용산구
# 4  환경부(한국자동차환경협회)  마장동사무소 앞(공중전화부스)      1  DC차데모+AC3상+DC콤보  서울특별시   성동구
#
#                                                   주소     이용가능시간     급속충전량  \
# 0        서울특별시 종로구 종로 157 , 지하주차장 4층 하층 T구역(훈정동 1-2)  24시간 이용가능  급속(50kW)
# 1  서울특별시 종로구 세종대로 189 , 지하주차장 4층 D구역 계단실 앞(세종로 80-1)  24시간 이용가능  급속(50kW)
# 2           서울특별시 중구 동호로 287 , 대형버스주차장(장충동2가 186-54)  24시간 이용가능  급속(50kW)
# 3                     서울특별시 용산구 한남동 산10-84 , 지상실외주차장  24시간 이용가능  급속(50kW)
# 4                        서울특별시 성동구 마장동 808 (마장동 808)  24시간 이용가능  급속(50kW)
#
#                           비고
# 0    주차비 5분 200원(저공해스티커 부착시)
# ...

# %%
char_df.tail()
# Out:
#       운영기관          충전소  충전기ID 충전기타입      지역   시군구                         주소  \
# 33291  울산시  영남알프스복합웰컴센터      2  DC콤보  울산광역시   울주군   울산광역시 울주군 상북면 등억알프스리 517
# 33292  울산시  영남알프스복합웰컴센터      1  DC콤보  울산광역시   울주군   울산광역시 울주군 상북면 등억알프스리 517
# 33293  울산시   언양읍 행정복지센터      1  DC콤보  울산광역시   울주군        울산광역시 울주군 언양읍 동문길 7
# 33294  울산시   화봉공원 공영주차장      2  DC콤보  울산광역시    북구         울산광역시 북구 화봉동 445-1
# 33295  울산시   화봉공원 공영주차장      1  DC콤보  울산광역시    북구         울산광역시 북구 화봉동 445-1
#
#           이용가능시간 급속충전량   비고
# 33291  24시간 이용가능   NaN  NaN
# 33292  24시간 이용가능   NaN  NaN
# 33293  24시간 이용가능   NaN  NaN
# 33294  24시간 이용가능   NaN  NaN
# 33295  24시간 이용가능   NaN  NaN

# %%
char_df.shape
# Out:
# (33296, 10)

# %%
char_df.columns
# Out:
# Index(['운영기관', '충전소', '충전기ID', '충전기타입', '지역', '시군구', '주소', '이용가능시간', '급속충전량',
#        '비고'],
#       dtype='object')

# %%
operater = char_df['운영기관'].value_counts().sort_values(ascending=False)
operater
# Out:
# 에버온               7745
# 케이티               5712
# 환경부(한국자동차환경협회)    4063
# 지엔텔               2094
# 차지비               2033
# 한국전기차충전서비스        1808
# 이카플러그             1506
# 한국전력              1432
# 제주전기자동차서비스        1383
# 대영채비              1335
# 에스트래픽             1012
# 타디스테크놀로지           849
# 파워큐브               673
# 제주특별자치도            442
# 클린일렉스              267
# 차지인                199
# 대구환경공단             143
# 매니지온               105
# GS칼텍스               90
# SK에너지               86
# 광주시                 59
# 기아자동차               54
# 울산시                 28
# 시그넷이브이              28
# 울릉군청                22
# 인천국제공항              16
# evMost              15
# 군포시                 14
# 서울시(한국자동차환경협회)      13
# 나주시                 13
# 한국컴퓨터               11
# 익산시                 10
# 제주테크노파크              7
# 제주에너지공사              7
# 보타리에너지               6
# 삼척시                  4
# 수원시                  3
# 전주시                  3
# 정읍시                  2
# 한국환경공단               2
# ...

# %%
plt.figure(figsize=(30,10))
plt.bar(operater.index, operater.values, label='운영기관별 충전소 개수', color='r')
plt.title('운영기관별 충전소 개수') 
plt.xlabel('운영기관')
plt.ylabel('충전소수')
plt.legend()
plt.show()
 #에버온 > 케이티> 환경부 순

# %%
#도시별 충전소 개수 
city = char_df['지역'].value_counts().sort_values(ascending=False)
city
# Out:
# 경기도         7349
# 서울특별시       3585
# 제주특별자치도     3109
# 경상북도        2140
# 경상남도        2042
# 충청남도        2030
# 전라남도        1810
# 전라북도        1673
# 강원도         1599
# 대구광역시       1361
# 부산광역시       1324
# 충청북도        1244
# 광주광역시       1236
# 인천광역시       1123
# 대전광역시        802
# 울산광역시        597
# 세종특별자치시      272
# Name: 지역, dtype: int64

# %%
plt.figure(figsize=(30,10))
plt.bar( city.index, city.values, label='도시별 충전소 개수', color='b')
plt.title('도시별 충전소 개수') 
plt.xlabel('도시')
plt.ylabel('충전소수')
plt.legend()
plt.show()

# %%
popu_df.T.iloc[1:,33].astype('int')
# Out:
# 서울     9689159
# 부산     3397598
# 대구     2424171
# 인천     2942233
# 광주     1452994
# 대전     1467556
# 울산     1138581
# 세종      351007
# 경기    13400615
# 강원     1541836
# 충북     1599102
# 충남     2120347
# 전북     1805937
# 전남     1850680
# 경북     2639763
# 경남     3342831
# 제주      673606
# Name: 33, dtype: int32

# %%
# 충전소 데이타 filtering 
map_df = char_df.filter(items=['지역','시군구','충전소','주소','급속충전량'])
map_df
# Out:
#            지역   시군구               충전소  \
# 0      서울특별시   종로구           종묘 공영주차장
# 1      서울특별시   종로구          세종로 공영주차장
# 2      서울특별시    중구         그랜드앰배서더 서울
# 3      서울특별시   용산구         한강진역 공영주차장
# 4      서울특별시   성동구   마장동사무소 앞(공중전화부스)
# ...       ...   ...               ...
# 33291  울산광역시   울주군        영남알프스복합웰컴센터
# 33292  울산광역시   울주군        영남알프스복합웰컴센터
# 33293  울산광역시   울주군         언양읍 행정복지센터
# 33294  울산광역시    북구         화봉공원 공영주차장
# 33295  울산광역시    북구         화봉공원 공영주차장
#
#                                                       주소     급속충전량
# 0            서울특별시 종로구 종로 157 , 지하주차장 4층 하층 T구역(훈정동 1-2)  급속(50kW)
# 1      서울특별시 종로구 세종대로 189 , 지하주차장 4층 D구역 계단실 앞(세종로 80-1)  급속(50kW)
# 2               서울특별시 중구 동호로 287 , 대형버스주차장(장충동2가 186-54)  급속(50kW)
# 3                         서울특별시 용산구 한남동 산10-84 , 지상실외주차장  급속(50kW)
# 4                            서울특별시 성동구 마장동 808 (마장동 808)  급속(50kW)
# ...                                                  ...       ...
# ...

# %%
# 완속 충전기에 대해 표시안되어 있음을 완속으로 변경 
map_df = map_df.replace(np.nan,'완속')
map_df
# Out:
#            지역   시군구               충전소  \
# 0      서울특별시   종로구           종묘 공영주차장
# 1      서울특별시   종로구          세종로 공영주차장
# 2      서울특별시    중구         그랜드앰배서더 서울
# 3      서울특별시   용산구         한강진역 공영주차장
# 4      서울특별시   성동구   마장동사무소 앞(공중전화부스)
# ...       ...   ...               ...
# 33291  울산광역시   울주군        영남알프스복합웰컴센터
# 33292  울산광역시   울주군        영남알프스복합웰컴센터
# 33293  울산광역시   울주군         언양읍 행정복지센터
# 33294  울산광역시    북구         화봉공원 공영주차장
# 33295  울산광역시    북구         화봉공원 공영주차장
#
#                                                       주소     급속충전량
# 0            서울특별시 종로구 종로 157 , 지하주차장 4층 하층 T구역(훈정동 1-2)  급속(50kW)
# 1      서울특별시 종로구 세종대로 189 , 지하주차장 4층 D구역 계단실 앞(세종로 80-1)  급속(50kW)
# 2               서울특별시 중구 동호로 287 , 대형버스주차장(장충동2가 186-54)  급속(50kW)
# 3                         서울특별시 용산구 한남동 산10-84 , 지상실외주차장  급속(50kW)
# 4                            서울특별시 성동구 마장동 808 (마장동 808)  급속(50kW)
# ...                                                  ...       ...
# ...

# %%
#급속 종류 코멘트 '급속'으로 일괄 변경 (update)
map_df = map_df.replace('급속(50kW)','급속')
map_df = map_df.replace('급속(200kW동시)','급속')
map_df = map_df.replace('급속(100kW멀티)','급속')
map_df = map_df.replace('급속(100kW동시)','급속')
map_df = map_df.replace('급속(400kW동시)','급속')
map_df = map_df.replace('급속(500kW동시)','급속')
map_df = map_df.replace('급속(600kW동시)','급속')
map_df = map_df.replace('급속(700kW동시)','급속')
map_df = map_df.replace('급속(1000kW동시)','급속')
map_df.head()
# Out:
#        지역   시군구               충전소  \
# 0  서울특별시   종로구           종묘 공영주차장
# 1  서울특별시   종로구          세종로 공영주차장
# 2  서울특별시    중구         그랜드앰배서더 서울
# 3  서울특별시   용산구         한강진역 공영주차장
# 4  서울특별시   성동구   마장동사무소 앞(공중전화부스)
#
#                                                   주소 급속/완속
# 0        서울특별시 종로구 종로 157 , 지하주차장 4층 하층 T구역(훈정동 1-2)    급속
# 1  서울특별시 종로구 세종대로 189 , 지하주차장 4층 D구역 계단실 앞(세종로 80-1)    급속
# 2           서울특별시 중구 동호로 287 , 대형버스주차장(장충동2가 186-54)    급속
# 3                     서울특별시 용산구 한남동 산10-84 , 지상실외주차장    급속
# 4                        서울특별시 성동구 마장동 808 (마장동 808)    급속

# %%
# 급속충전량 칼럼 급속/완속으로 변경 
map_df = map_df.rename(columns = {'급속충전량':'급속/완속'})
map_df
# Out:
#            지역   시군구               충전소  \
# 0      서울특별시   종로구           종묘 공영주차장
# 1      서울특별시   종로구          세종로 공영주차장
# 2      서울특별시    중구         그랜드앰배서더 서울
# 3      서울특별시   용산구         한강진역 공영주차장
# 4      서울특별시   성동구   마장동사무소 앞(공중전화부스)
# ...       ...   ...               ...
# 33291  울산광역시   울주군        영남알프스복합웰컴센터
# 33292  울산광역시   울주군        영남알프스복합웰컴센터
# 33293  울산광역시   울주군         언양읍 행정복지센터
# 33294  울산광역시    북구         화봉공원 공영주차장
# 33295  울산광역시    북구         화봉공원 공영주차장
#
#                                                       주소 급속/완속
# 0            서울특별시 종로구 종로 157 , 지하주차장 4층 하층 T구역(훈정동 1-2)    급속
# 1      서울특별시 종로구 세종대로 189 , 지하주차장 4층 D구역 계단실 앞(세종로 80-1)    급속
# 2               서울특별시 중구 동호로 287 , 대형버스주차장(장충동2가 186-54)    급속
# 3                         서울특별시 용산구 한남동 산10-84 , 지상실외주차장    급속
# 4                            서울특별시 성동구 마장동 808 (마장동 808)    급속
# ...                                                  ...   ...
# ...

# %%
#도시별 충전소 수 (update)
#gubeul = map_df.groupby(['지역','시군구']).agg([len])
citybeul = map_df.groupby(['지역']).agg([len])
citybeul
# Out:
#            시군구   충전소    주소 급속/완속
#            len   len   len   len
# 지역
# 강원도       1599  1599  1599  1599
# 경기도       7349  7349  7349  7349
# 경상남도      2042  2042  2042  2042
# 경상북도      2140  2140  2140  2140
# 광주광역시     1236  1236  1236  1236
# 대구광역시     1361  1361  1361  1361
# 대전광역시      802   802   802   802
# 부산광역시     1324  1324  1324  1324
# 서울특별시     3585  3585  3585  3585
# 세종특별자치시    272   272   272   272
# 울산광역시      597   597   597   597
# 인천광역시     1123  1123  1123  1123
# 전라남도      1810  1810  1810  1810
# 전라북도      1673  1673  1673  1673
# 제주특별자치도   3109  3109  3109  3109
# 충청남도      2030  2030  2030  2030
# 충청북도      1244  1244  1244  1244

# %%
#도시별 충전소수_급속/완속 (update)
citybeul_fs = map_df.groupby(['지역','급속/완속']).agg([len])
citybeul_fs
# Out:
#                  시군구   충전소    주소
#                  len   len   len
# 지역       급속/완속
# 강원도      급속      394   394   394
#          완속     1205  1205  1205
# 경기도      급속      508   508   508
#          완속     6841  6841  6841
# 경상남도     급속      295   295   295
#          완속     1747  1747  1747
# 경상북도     급속      488   488   488
#          완속     1652  1652  1652
# 광주광역시    급속       73    73    73
#          완속     1163  1163  1163
# 대구광역시    급속      129   129   129
#          완속     1232  1232  1232
# 대전광역시    급속       95    95    95
#          완속      707   707   707
# 부산광역시    급속       83    83    83
#          완속     1241  1241  1241
# 서울특별시    급속      262   262   262
#          완속     3323  3323  3323
# 세종특별자치시  급속       34    34    34
#          완속      238   238   238
# 울산광역시    급속      114   114   114
#          완속      483   483   483
# 인천광역시    급속      125   125   125
#          완속      998   998   998
# 전라남도     급속      369   369   369
#          완속     1441  1441  1441
# ...

# %%
#울산시 충전소 정보 데이타 
ulsan_map_df = map_df.loc[map_df['지역'].str.contains('울산광역시')]
ulsan_map_df
# Out:
#            지역   시군구            충전소  \
# 83     울산광역시    중구     울산 중구 동천체육관
# 84     울산광역시    동구    울산 동구 전하체육센터
# 85     울산광역시    북구         울산시 북구청
# 86     울산광역시    북구       농소2동 주민센터
# 87     울산광역시   울주군   울산 울주군 서생면사무소
# ...       ...   ...            ...
# 33291  울산광역시   울주군     영남알프스복합웰컴센터
# 33292  울산광역시   울주군     영남알프스복합웰컴센터
# 33293  울산광역시   울주군      언양읍 행정복지센터
# 33294  울산광역시    북구      화봉공원 공영주차장
# 33295  울산광역시    북구      화봉공원 공영주차장
#
#                                                    주소 급속/완속
# 83             울산광역시 중구 염포로 85 동천 체육관 동편 주차장(남외동 673)    급속
# 84         울산광역시 동구 봉수로 285 전하체육센터 주차장 입구옆(전하동 559-8)    급속
# 85                         울산광역시 북구 연암동 산업로 1010 북구청     급속
# 86                         울산광역시 북구 찬샘1길 24 (찬샘1길 24)    급속
# 87     울산광역시 울주군 서생면 해맞이로 894 서생면사무소 청사 건물 출입구 우측 주차장    급속
# ...                                               ...   ...
# 33291                       울산광역시 울주군 상북면 등억알프스리 517     완속
# ...

# %%
# 울산 급속 충전 vs 완속 충전기 개수 
ulsan_fast = ulsan_map_df['급속/완속'].value_counts().sort_values(ascending=False)
ulsan_fast
# Out:
# 완속    483
# 급속    114
# Name: 급속/완속, dtype: int64

# %%
#울산 시군구별 충전소 개수 
ulsan_elec_qty_df = ulsan_map_df['시군구'].value_counts().sort_values(ascending=False)
ulsan_elec_qty_df
# Out:
# 울주군     224
# 남구      153
# 북구       89
# 중구       88
# 동구       43
# Name: 시군구, dtype: int64

# %%
#울산 시군구별 급속/완속 충전기 
#ulsan_elec__fs = ulsan_map_df.groupby('시군구')['급속/완속'].value_counts().sort_values(ascending=False)
ulsan_elec__fs = ulsan_map_df.groupby('시군구')['급속/완속'].value_counts()
ulsan_elec__fs
# Out:
# 시군구   급속/완속
# 남구    완속       114
#       급속        39
# 동구    완속        32
#       급속        11
# 북구    완속        58
#       급속        31
# 울주군   완속       203
#       급속        21
# 중구    완속        76
#       급속        12
# Name: 급속/완속, dtype: int64

# %%
# 인구대비 충전소 비율 (??)

# 전기차 수 대비 충전소 비율 (??)

# %%
for i in ulsan_map_df.index:
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + ulsan_map_df.loc[i, '주소']
    rest_api_key = 'ff47bfb2076f314e4f49c060d75b9464'
    header = {'Authorization': 'KakaoAK ' + rest_api_key}
    resp = requests.get(url, headers=header)
    
    if resp.status_code == 200:
        jsondata = resp.json()
        if jsondata["meta"]["total_count"] == 0 :
            ulsan_map_df.loc[i, '위도'] = np.nan
            ulsan_map_df.loc[i, '경도'] = np.nan
        else :
            ulsan_map_df.loc[i, '위도'] = jsondata["documents"][0]["address"]["y"]
            ulsan_map_df.loc[i, '경도'] = jsondata["documents"][0]["address"]["x"]
    else:
        ulsan_map_df.loc[i, '위도'] = "ERROR[" + str(r.status_code) + "]"
        ulsan_map_df.loc[i, '경도'] = "ERROR[" + str(r.status_code) + "]"
    
ulsan_map_df
# Out:
# C:\Users\WS-home\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\WS-home\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\WS-home\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ulsan_map_df = ulsan_map_df.dropna()

# %%
ulsan_map = folium.Map(location=[35.5610411920161,129.350485875962], zoom_start=12, tiles='OpenStreetMap')
ulsan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
marker = folium.Marker([35.5610411920161,129.350485875962], popup='동천체육관', tooltip='환영합니다', icon=folium.Icon(icon='home', color='red'))
marker.add_to(ulsan_map)
ulsan_map.save('울산_충전소_현황.html')
ulsan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도로 표기
for i in ulsan_map_df.index:
    lat = ulsan_map_df.loc[i, '위도']
    lng = ulsan_map_df.loc[i, '경도']
    contents = folium.Popup('<b>'+ulsan_map_df.loc[i, '충전소']+'</b>'+'<br>'+ulsan_map_df.loc[i, '주소'], max_width=300)
    
    mark_type = ulsan_map_df.loc[i, '급속/완속']
    
    if mark_type == '급속':
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='home', color='red'))
    elif mark_type == '완속':
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='glass', color='black'))
    else :
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='bookmark', color='blue'))

    marker.add_to(ulsan_map)
    
ulsan_map.save('울산_충전소_현황.html')
ulsan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
